# %%
import pandas as pd
import numpy as np
from scipy.stats import skew, kurtosis

# Load Datasets
uci_diabetes = pd.read_csv("uci_diabetes.csv")
pima_diabetes = pd.read_csv("pima_diabetes.csv")

# Display Dataset Samples
print("UCI Diabetes Dataset Sample:")
print(uci_diabetes.head())

print("\nPima Indians Diabetes Dataset Sample:")
print(pima_diabetes.head())

# Define Relevant Numerical Columns
numerical_columns = [
    "Glucose",
    "BloodPressure",
    "SkinThickness",
    "Insulin",
    "BMI",
    "DiabetesPedigreeFunction",
    "Age"
]

# Function for Univariate Analysis
def univariate_analysis(df, columns):
    stats = {}

    for col in columns:
        stats[col] = {
            "Mean": np.mean(df[col]),
            "Median": np.median(df[col]),
            "Mode": df[col].mode()[0],
            "Variance": np.var(df[col], ddof=1),
            "Standard Deviation": np.std(df[col], ddof=1),
            "Skewness": skew(df[col]),
            "Kurtosis": kurtosis(df[col])
        }

    return pd.DataFrame(stats).T

# Perform Univariate Analysis
uci_stats = univariate_analysis(uci_diabetes, numerical_columns)
pima_stats = univariate_analysis(pima_diabetes, numerical_columns)

# Display Results
print("\n==============================")
print("UCI Diabetes Dataset Statistics")
print("==============================")
print(uci_stats)

print("\n==============================")
print("Pima Indians Diabetes Dataset Statistics")
print("==============================")
print(pima_stats)
# Out:
# UCI Diabetes Dataset Sample:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      124             91             98      552  34.7
# 1           14      195            111             19      317  38.0
# 2           10      125            118             60      501  20.9
# 3            7       58             89             34      827  42.2
# 4            6      123             72             49      380  22.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     1.370   76        0
# 1                     1.270   50        1
# 2                     0.308   77        1
# 3                     1.659   50        1
# 4                     2.064   67        1
#
# Pima Indians Diabetes Dataset Sample:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0           16      103             44             87      659  43.5
# 1           10      164            100             39      320  37.1
# 2            2      188             58             96      724  46.4
# 3            7      137             32             16      432  31.2
# 4           13       98            112             87      108  37.3
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.947   22        1
# 1                     2.027   62        1
# 2                     1.332   64        1
# 3                     0.336   28        1
# 4                     0.366   63        0
#
# ==============================
# UCI Diabetes Dataset Statistics
# ==============================
#                                 Mean   Median     Mode      Variance  \
# Glucose                   123.850679  123.000   96.000   1947.818922
# BloodPressure              75.022624   75.000  116.000    698.502888
# SkinThickness              50.486425   49.500   97.000    878.989611
# Insulin                   425.085973  421.000  647.000  59680.686469
# BMI                        33.835747   33.900   32.700     86.837404
# DiabetesPedigreeFunction    1.290403    1.297    0.224      0.484033
# Age                        50.214932   50.000   33.000    291.819913
#
#                           Standard Deviation  Skewness  Kurtosis
# Glucose                            44.134102  0.013897 -1.204660
# BloodPressure                      26.429205  0.048561 -1.139163
# SkinThickness                      29.647759  0.009031 -1.244866
# Insulin                           244.296309  0.011030 -1.201130
# BMI                                 9.318659 -0.013203 -1.214710
# DiabetesPedigreeFunction            0.695725 -0.036760 -1.140873
# Age                                17.082737  0.070775 -1.148022
#
# ==============================
# Pima Indians Diabetes Dataset Statistics
# ==============================
#                                 Mean    Median     Mode      Variance  \
# Glucose                   125.656250  127.0000   71.000   1925.055085
# BloodPressure              76.958333   78.0000  100.000    703.985224
# SkinThickness              49.442708   50.0000   16.000    838.784197
# Insulin                   416.644531  425.0000  478.000  61247.997336
# BMI                        33.849089   33.9000   19.700     85.832959
# DiabetesPedigreeFunction    1.262384    1.2345    0.371      0.498734
# Age                        49.602865   49.0000   53.000    301.157593
#
#                           Standard Deviation  Skewness  Kurtosis
# Glucose                            43.875450 -0.048127 -1.259137
# BloodPressure                      26.532720 -0.074613 -1.203170
# SkinThickness                      28.961771  0.005669 -1.232676
# Insulin                           247.483327  0.020429 -1.195249
# BMI                                 9.264608  0.014695 -1.188777
# DiabetesPedigreeFunction            0.706211  0.066982 -1.209138
# Age                                17.353893  0.074997 -1.189705
