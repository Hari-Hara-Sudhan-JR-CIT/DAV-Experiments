# %%
# Import Libraries
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind

# Load the Datasets
uci_diabetes = pd.read_csv("uci_diabetes.csv")
pima_diabetes = pd.read_csv("pima_diabetes.csv")

# Select Relevant Numerical Columns
numerical_columns = ["Glucose", "BloodPressure", "BMI"]

# Perform Independent T-Test
t_test_results = {}

for col in numerical_columns:
    
    t_stat, p_value = ttest_ind(
        uci_diabetes[col],
        pima_diabetes[col],
        equal_var=False
    )
    
    t_test_results[col] = {
        "T-statistic": t_stat,
        "P-value": p_value
    }

# Convert Results to DataFrame
t_test_df = pd.DataFrame(t_test_results).T

# Display Results
print("T-Test Results:")
print(t_test_df)

# Interpretation
print("\nInterpretation:")

alpha = 0.05

for col in numerical_columns:
    p_value = t_test_results[col]["P-value"]

    if p_value < alpha:
        print(f"{col}: Reject the null hypothesis - Significant difference exists.")
    else:
        print(f"{col}: Fail to reject the null hypothesis - No significant difference.")
# Out:
# T-Test Results:
#                T-statistic   P-value
# Glucose          -0.686702  0.492444
# BloodPressure    -1.224992  0.220891
# BMI              -0.024032  0.980833
#
# Interpretation:
# Glucose: Fail to reject the null hypothesis - No significant difference.
# BloodPressure: Fail to reject the null hypothesis - No significant difference.
# BMI: Fail to reject the null hypothesis - No significant difference.
