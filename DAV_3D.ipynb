# %%
# Import Libraries
import pandas as pd

# Load the Datasets
uci_diabetes = pd.read_csv("uci_diabetes.csv")
pima_diabetes = pd.read_csv("pima_diabetes.csv")

# Display Summary Statistics
print("==============================================")
print("UCI Diabetes Dataset Summary Statistics")
print("==============================================")
print(uci_diabetes.describe())

print("\n==============================================")
print("Pima Indians Diabetes Dataset Summary Statistics")
print("==============================================")
print(pima_diabetes.describe())

# Enter the R² Scores obtained from Program 4
uci_r2 = 0.78
pima_r2 = 0.72

# Enter the Accuracy Scores obtained from Program 3
uci_accuracy = 82.4
pima_accuracy = 79.1

# Display Comparison
print("\n==============================================")
print("Regression Model Performance Comparison")
print("==============================================")

print(f"Linear Regression R² Score")
print(f"UCI Diabetes Dataset   : {uci_r2}")

print(f"Pima Diabetes Dataset  : {pima_r2}")

print("\nLogistic Regression Accuracy")

print(f"UCI Diabetes Dataset   : {uci_accuracy}%")
print(f"Pima Diabetes Dataset  : {pima_accuracy}%")
# Out:
# ...
# UCI Diabetes Dataset Summary Statistics
# ...
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   442.000000  442.000000     442.000000     442.000000  442.000000
# mean      8.029412  123.850679      75.022624      50.486425  425.085973
# std       5.378343   44.134102      26.429205      29.647759  244.296309
# min       0.000000   50.000000      30.000000       0.000000    0.000000
# 25%       3.000000   87.000000      53.250000      25.000000  219.250000
# 50%       8.000000  123.000000      75.000000      49.500000  421.000000
# 75%      13.000000  162.000000      96.750000      76.750000  639.250000
# max      17.000000  199.000000     121.000000      99.000000  844.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  442.000000                442.000000  442.000000  442.000000
# mean    33.835747                  1.290403   50.214932    0.484163
# ...
